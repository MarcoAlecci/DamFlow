# %% [markdown]
# ## 🦾 Sub-Phase 3: Category-Based Anomaly Detection Training

# %%
# Imports
from   dotenv   import load_dotenv
import pandas   as pd
import datetime
import sys
import os

# Add the upper folder to sys.path
sys.path.insert(0, "../")
from   Training    import TrainingManager
from   RedisClient import RedisClient
from   App         import App

# %% [markdown]
# #### Parameters

# %%
# Model Folder --> Where to save models
MODELS_PATH = "../../../0_Data/MODELS/"

# TMP Folder
TMP_PATH    = "../../../0_Data/TMP/"

# %% [markdown]
# #### Initialization

# %%
print("⚡ Start - {} ⚡\n".format(datetime.datetime.now()))
startTime = datetime.datetime.now()
# Out:
# ⚡ Start - 2024-08-02 17:18:05.608348 ⚡

# %%
# Create TMP Folder
if not os.path.exists(TMP_PATH):
	os.makedirs(TMP_PATH)
	print("📁🆕 Folder created       : {}\n".format(TMP_PATH))
else:
	print("📁✅ Folder already exists: {}\n".format(TMP_PATH))

# Create MODELS Folder
if not os.path.exists(MODELS_PATH):
	os.makedirs(MODELS_PATH)
	print("📁🆕 Folder created       : {}\n".format(MODELS_PATH))
else:
	print("📁✅ Folder already exists: {}\n".format(MODELS_PATH))
# Out:
# 📁✅ Folder already exists: ../../../0_Data/TMP/
#
# 📁🆕 Folder created       : ../../../0_Data/MODELS/

# %% [markdown]
# #### 📥 1) Load Data

# %%
REDIS_PREFIX = "test"

# %%
DATASET          = "androcatset"
DIRECTION        = "backward"
SOURCES_APPROACH = "nosources"

redisProjectKey = REDIS_PREFIX + ".{}.{}.{}".format(DATASET, DIRECTION, SOURCES_APPROACH)
print("--- 🔑 Redis Key: ", redisProjectKey)
# Out:
# --- 🔑 Redis Key:  test.androcatset.backward.nosources

# %% [markdown]
# 📡 Redis Connection

# %%
# Load .env file
load_dotenv()
redisClientExtraction = RedisClient(host=os.getenv("REDIS_SERVER"), 
                                    port=os.getenv("REDIS_PORT"), 
                                    db=os.getenv("REDIS_DB"), 
                                    password=os.getenv("REDIS_PSW"), 
                                    projectKey = redisProjectKey)

# %%
# Paths
INPUT_PATH   = "../../../0_Data/2_AndroCatSet_TrainingSet.csv"
INPUT_PATH   = "../../../0_Data/1_AndroCatSet_Mini.csv"

# Read the data
appsDF = pd.read_csv(INPUT_PATH)
print("--- #️⃣ Apps: {} ".format(appsDF.shape[0]))

# TEST
#appsDF = appsDF.head(3)
appsDF.head(10)
# Out:
# --- #️⃣ Apps: 50
#                                               sha256  \
# 0  9B30837BD2474AC3623A43D052F7ADC4C63E4AA9981F0F...
# 1  686DE8D8A0D08992CB135BC7A0500D0109D9697A1140B8...
# 2  A49864DCC90F6730569455BDFA39B4B7CF70AE0C34D656...
# 3  85C80B7ED3799C04CBD107DD3004F91ED4DC2BF8D75C35...
# 4  66442DEF269FF22FB4177759343D973DA1A6A3AFE2ECE3...
# 5  E62452B248DDDC34646D98BEC604C236B865115DA1CD4B...
# 6  D35EDCE75773CB40CAC2BBD6AC294DE8103F3B7CA11DD6...
# 7  0708505CD2893C15589BD3BCBEEA22F414B0EF23B7BC11...
# 8  5482249D7EF2DCA96CDC791433F86EE0C962A1F71712C4...
# 9  F1D6B18311B1C80936935BC6199A338E599AF4509E0DAB...
#
#                                     pkgName     classID googlePlayCategoryID  \
# 0                           my.android.calc  Calculator                TOOLS
# 1                   com.vpn.basiccalculator  Calculator                TOOLS
# 2                 com.ba.fractioncalculator  Calculator            EDUCATION
# 3                           de.sfr.calctape  Calculator              FINANCE
# 4  com.digitalchemy.calculator.freefraction  Calculator                TOOLS
# 5   com.digitalchemy.calculator.freedecimal  Calculator                TOOLS
# 6                          com.candl.athena  Calculator                TOOLS
# 7                 com.dencreak.dlcalculator  Calculator         PRODUCTIVITY
# 8       calculator.innovit.com.calculatrice  Calculator                TOOLS
# 9                         apps.r.calculator  Calculator                TOOLS
#
#                                googlePlayDescription
# 0  Handiness universal percentage calculator for ...
# 1  CITIZEN CALCULATOR by ANGEL NX is best Mobile ...
# 2  <b>Free offline fraction calculator</b> ✌, sup...
# 3  What happens if you combine a standard calcula...
# 4  Fraction Calculator Plus is your best way to d...
# 5  <strong>Calculator Plus - a perfect calculator...
# 6  Express your style with the free calculator ma...
# 7  This calculator allows you to easily handle al...
# 8  Calculator is the essential tool for your smar...
# 9  Calculator allows you to perform simple and co...

# %% [markdown]
# #### 🏷️ 2) Load Data Flows Embeddings and Train a Model.

# %%
# Where embeddingsa are stores
redisClientEmbedding  = RedisClient(host=os.getenv("REDIS_SERVER"), 
									port=os.getenv("REDIS_PORT"), 
									db=os.getenv("REDIS_DB"), 
									password=os.getenv("REDIS_PSW"), 
									projectKey = REDIS_PREFIX + ".embeddings")

# %%
EMBEDDING_MODEL = "gpt"
#EMBEDDING_MODEL = "codebert"
#EMBEDDING_MODEL = "sfr"

# %%
# Group by category
groupedDF = appsDF.groupby('classID')

# %%
for categoryID, categoryDF in groupedDF:
	print("\n🏷️ --- category ID: {} --- 🏷️".format(categoryID))
	print("--- #️⃣ Num. of apps: {}".format(categoryDF.shape[0]))

	# TRAINING MANAGER
	trainingManager = TrainingManager(EMBEDDING_MODEL)

	def processRow(row):
		# Print message 
		print("\n--- 🔑 Analyzing APK: {} 🔑 ---".format(row['sha256']))

		# Create App instance
		app = App(row['sha256'], row['pkgName'], row['classID'])

		# Get Data Flows From Redis
		app.downloadDataFlowsFromRedis(redisClient = redisClientExtraction)

		#Check if dataFlows have been extracted and are not empty.
		if(app.dataFlows is not None and not app.dataFlows.isEmpty()):
			
			app.downloadPairsEmbeddingsFromRedis(redisClientEmbedding, EMBEDDING_MODEL)

			# Load DataFlows into Embeddings Manager
			trainingManager.loadEmbeddingsFromApp(app.embeddings[EMBEDDING_MODEL])

		print("--- ⏱️ Loaded into Training Manager\n--- ⏱️ Time: {} \n--- ⏱️ Time Elapsed: {} seconds".format(datetime.datetime.now(), int((datetime.datetime.now() - startTime).total_seconds())))
		print("--- 📐 New Embedding shape: {}".format(trainingManager.embeddings.shape))

	# Apply the function to each row in the DataFrame
	_ = categoryDF.apply(processRow, axis=1)

	print("\n\n--- ✅ Training Manager Fully Loaded")
	print("--- ⏱️ Time: {} \n--- ⏱️ Time Elapsed: {} seconds".format(datetime.datetime.now(), int((datetime.datetime.now() - startTime).total_seconds())))

	# Print Loaded Manager
	print(trainingManager)

	# Train the model
	try:
		trainingManager.trainAnomalyDetectionModel(MODELS_PATH + "{}/{}.joblib".format(categoryID, EMBEDDING_MODEL))
	except:
		continue

	# Print Results
	print(trainingManager.trainingResults)
# Out:
# 🏷️ --- category ID: Calculator --- 🏷️
# --- #️⃣ Num. of apps: 10
#
# --- 🔑 Analyzing APK: 9B30837BD2474AC3623A43D052F7ADC4C63E4AA9981F0F9DAA658F825EBDB224 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.698642
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 686DE8D8A0D08992CB135BC7A0500D0109D9697A1140B8EDADF19B3B3BD2220C 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.703518
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: A49864DCC90F6730569455BDFA39B4B7CF70AE0C34D656D078790CBA3521C0A0 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.705586
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 85C80B7ED3799C04CBD107DD3004F91ED4DC2BF8D75C3589176EEC1D61F3D02E 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.710352
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 66442DEF269FF22FB4177759343D973DA1A6A3AFE2ECE3C7DE8C89ECDB10D93E 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.712113
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: E62452B248DDDC34646D98BEC604C236B865115DA1CD4B1958B7B2C1791D9D74 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.714265
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: D35EDCE75773CB40CAC2BBD6AC294DE8103F3B7CA11DD6B971637E0837FC8F61 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.715927
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 0708505CD2893C15589BD3BCBEEA22F414B0EF23B7BC1198E17BCBA2404436ED 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.718450
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 5482249D7EF2DCA96CDC791433F86EE0C962A1F71712C4A2A060DAACB853DD78 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.720300
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: F1D6B18311B1C80936935BC6199A338E599AF4509E0DAB7688D4745FDC93469E 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.722312
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
#
# --- ✅ Training Manager Fully Loaded
# --- ⏱️ Time: 2024-08-02 17:18:05.722744
# --- ⏱️ Time Elapsed: 0 seconds
#
# --- ⭐ Training Manager ⭐---
# --- ⚙️ Embedding Model  : gpt
# --- #️⃣ Number of apps loaded  : 0
# --- 📐 Feature Vectors Shape [Num Data Flow Pairs, Length of Feature Vectors]
# --- 📐 Shape : (0,)
#
# --- 🦾 TRAINING 🦾 ---
#
# --- ⚠️ Error: Embeddings Not Loaded
#
# 🏷️ --- category ID: Dating --- 🏷️
# --- #️⃣ Num. of apps: 10
#
# --- 🔑 Analyzing APK: B009047913B5FD03710B5FD9B2930FCDEE25D3997DDFB3E9E5CB01682EE1CC7E 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.725814
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 64636C625A39F001789953483CCF3AC8FA55CC67C4E0B4ECA93D1886D9DE69C4 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.727878
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: BCAAD7AD9C32E12780960B00DB3B0F4FEDD7E9D104FE13A30D29B96A92502001 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.729680
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 2E921760CFE68C424BDF27E3CB1FF279C848DF53DF1024363D42BE9A2A6CF8B4 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.731296
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 6024878D0B86E28970072640B4FDF65A2555D8A5F15BF948B827586761D934E1 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.732775
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: FADDE389EEDF752EB9CA23507EF58F4D3F080C62D76D9A4DFD22BDC2478B4729 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.735038
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 4E3A0FB7FF6AF66E13CDDFAFB3DEEB24170AD3ECE235D8B91EA9FBBEC256AA8C 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:05.737094
# --- ⏱️ Time Elapsed: 0 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: B4D490CB032A7C0EAC1A732FFC901C1F15F7A918BD40F1585DE5F1C4F2A01F8A 🔑 ---
# --- ✅ Data Flows Availaible on Redis
# --- 💾 Memory Usage: 569.73 MB [1.78% of total]
# --- ⚙️ Data Flows Pairs : 956
# --- ✅ PAIRS Embeddings Loaded From Redis --> gpt
# --- ✅ Training Data Loaded
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.472685
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (956, 3072)
#
# --- 🔑 Analyzing APK: 569F53A91CF099FD596637F7028D685E67C0DE5BE8BC7BD730975FC2EB4E668F 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.474664
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (956, 3072)
#
# --- 🔑 Analyzing APK: 175F23DFFCB58C8CD353B2BC88B6163430188E881974ADF510E0BA69A7032395 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.476300
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (956, 3072)
#
#
# --- ✅ Training Manager Fully Loaded
# --- ⏱️ Time: 2024-08-02 17:18:09.476632
# --- ⏱️ Time Elapsed: 3 seconds
#
# --- ⭐ Training Manager ⭐---
# --- ⚙️ Embedding Model  : gpt
# --- #️⃣ Number of apps loaded  : 1
# --- 📐 Feature Vectors Shape [Num Data Flow Pairs, Length of Feature Vectors]
# --- 📐 Shape : (956, 3072)
#
# --- 🦾 TRAINING 🦾 ---
# --- ⏳ Start at    : 2024-08-02 17:18:09
# --- ⏳ Finished at : 2024-08-02 17:18:09
# --- ⏳ Time elapsed: 0.03 seconds
# --- 🧾 Number of Outliers Detected: 305
# --- 💾 Created directory: ../../../0_Data/MODELS/Dating
# --- 💾 Model saved : ../../../0_Data/MODELS/Dating/gpt.joblib
#
# --- 🚀 Training Results 🚀 ---
# --- 📦 Model                 : OneClassSVM(cache_size=500, gamma=0.001, nu=0.005)
# --- 💾 Model Path            : ../../../0_Data/MODELS/Dating/gpt.joblib
# --- 📐 Input Size            : (956, 3072)
# --- ⭕ Number of Outliers    : 305 (31.90%)
# ------------------------------
#
#
#
# 🏷️ --- category ID: Navigator --- 🏷️
# --- #️⃣ Num. of apps: 10
#
# --- 🔑 Analyzing APK: 803C40694759D696A0BBDFFBDED5889235F1D6487557EFA7A3F59699B76998D4 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.509317
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 3C9A3439E2E687EF2F5690919C5C1DB615B2D6E6616DDE29583615F6F1E2DDB9 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.511276
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: F1E9CEBB30C2E663992990F5D488AD14F6A639FF896D088A8524E1FA0CCFF9F3 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.513323
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 3010B4EDB0FE00E5865CF7543ECB98BE8B45C97677CFA9DC6062D2C16FB763CF 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.514920
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 4B85BBC12B37C1C105C9F77F1AE792FC24F66A377057DCC8F3AB1162750148ED 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.516805
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 8233165B59FE007FC08A2CEF827320D062AC01D2462839A09F6E6BBBD1DE7330 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.518794
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 77BD8161822ACD9586DCFC07A69571E2B4A732DFDB8DA78AE398048D03E936B4 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.520862
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: FFE7C65504C58B02526C9C583DD709D527EEE02F5B0473A797F5CE360E3E52FB 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.522624
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 239E01E72327E7167FE5E01D03ABE71D05812B9AF69702D57F2EA3C916B59D29 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.524454
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: E04AB5428175C816DCA9820867ECF35F490AE825CABDB3069EFE70D82B58E035 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.526221
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
#
# --- ✅ Training Manager Fully Loaded
# --- ⏱️ Time: 2024-08-02 17:18:09.526574
# --- ⏱️ Time Elapsed: 3 seconds
#
# --- ⭐ Training Manager ⭐---
# --- ⚙️ Embedding Model  : gpt
# --- #️⃣ Number of apps loaded  : 0
# --- 📐 Feature Vectors Shape [Num Data Flow Pairs, Length of Feature Vectors]
# --- 📐 Shape : (0,)
#
# --- 🦾 TRAINING 🦾 ---
#
# --- ⚠️ Error: Embeddings Not Loaded
#
# 🏷️ --- category ID: Wallpaper --- 🏷️
# --- #️⃣ Num. of apps: 10
#
# --- 🔑 Analyzing APK: 3A0E83F8D40F5859986C00CAA057E0DF267E95D73D851CA7D08792083C9C4E62 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.528463
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 77A6171ECED34C97493667E8E5ED1B9849D45D54BA6A26619048D32180D2AB5B 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.530183
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: FACD8C418E6FCCFEB1309BDB91EE71BD8408683F5D53828CDBD85E3FD1F6CD34 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.531728
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 8D2292A516A361177939527DD2E598F3C045CC10974AD2B27BF593EF06498233 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.533950
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: D35F61F22175CD85DA9BD778A8C538F5944413AB3B803C611F7B3E22B54022FA 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:09.536501
# --- ⏱️ Time Elapsed: 3 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 3F5412D8D6589535311F53935B0E6CD16B70780F02F4D3B8A1463705CF962173 🔑 ---
# --- ✅ Data Flows Availaible on Redis
# --- 💾 Memory Usage: 572.24 MB [1.79% of total]
# --- ⚙️ Data Flows Pairs : 1049
# --- ✅ PAIRS Embeddings Loaded From Redis --> gpt
# --- ✅ Training Data Loaded
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.452851
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (1049, 3072)
#
# --- 🔑 Analyzing APK: A0F1CDBA64DBF0B0BF485F8634A766613D6AF35D0F623E54CBB18A36BBF3D5DA 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.454950
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (1049, 3072)
#
# --- 🔑 Analyzing APK: E46B89E057006324C2716004E810E6E1874D07AA2C7D8E61F94F97E6FDCC7045 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.456541
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (1049, 3072)
#
# --- 🔑 Analyzing APK: E35F6D0F5AD608B4B7816F524C291AF96DA9E4537E526653AEE5EAC83E5AE5F2 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.458266
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (1049, 3072)
#
# --- 🔑 Analyzing APK: ABC9A8FFA1CA09E5B1154288E383FFB27197B0CC9246A19A8617A611F1ED466C 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.460056
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (1049, 3072)
#
#
# --- ✅ Training Manager Fully Loaded
# --- ⏱️ Time: 2024-08-02 17:18:13.460385
# --- ⏱️ Time Elapsed: 7 seconds
#
# --- ⭐ Training Manager ⭐---
# --- ⚙️ Embedding Model  : gpt
# --- #️⃣ Number of apps loaded  : 1
# --- 📐 Feature Vectors Shape [Num Data Flow Pairs, Length of Feature Vectors]
# --- 📐 Shape : (1049, 3072)
#
# --- 🦾 TRAINING 🦾 ---
# --- ⏳ Start at    : 2024-08-02 17:18:13
# --- ⏳ Finished at : 2024-08-02 17:18:13
# --- ⏳ Time elapsed: 0.05 seconds
# --- 🧾 Number of Outliers Detected: 230
# --- 💾 Created directory: ../../../0_Data/MODELS/Wallpaper
# --- 💾 Model saved : ../../../0_Data/MODELS/Wallpaper/gpt.joblib
#
# --- 🚀 Training Results 🚀 ---
# --- 📦 Model                 : OneClassSVM(cache_size=500, gamma=0.001, nu=0.005)
# --- 💾 Model Path            : ../../../0_Data/MODELS/Wallpaper/gpt.joblib
# --- 📐 Input Size            : (1049, 3072)
# --- ⭕ Number of Outliers    : 230 (21.93%)
# ------------------------------
#
#
#
# 🏷️ --- category ID: Weather --- 🏷️
# --- #️⃣ Num. of apps: 10
#
# --- 🔑 Analyzing APK: 26602F49FB24212BE3A86D956E74DAA8FD04175D0681F019A885F9106A6D8C5C 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.513578
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 3098BB50A8837400B30164B218399F4CCC0C7C5FB4F23787F4643065ABB4EBAC 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.515500
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: EA2CCEBFC2212317EA6E57ADAF05EC9932663A281CFE50E230F3A2ABD1225576 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.517488
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: AFE066005BDF8FBBFD2F11ECBDBAF16B8957258FE364EB2D4861A90E26C5DC93 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.519496
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 391BA992DE85B56D3298971491AF8A916EDACCA14EEC33344CF728EFEFBA936F 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.521205
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: C7BA5E8EDF13C504E60A6E4A9CF10FB4A448D805D6AA17A8C87067BD0822CF21 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.523317
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 8D499B4E7BE8CEDBB4A4447E5660B3936F15AD6821BD7603901089D62AE650D6 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.524991
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 445B0A8EC8C33C9ACC1DD64C7FB2970DB2FA3A8E7EB93347690568A4E7CF69CF 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.526645
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: D5048BC3597E62652EFB38C565791F44099213BBF3504D8B54EE01717D9B9A37 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.528533
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
# --- 🔑 Analyzing APK: 90AA0ECA07AFCAD8A840775B81C5A437DC797D8D5C77FA38B06AEA5493D998D2 🔑 ---
# --- ❌ Data Flows Unavailaible on Redis
# --- ⏱️ Loaded into Training Manager
# --- ⏱️ Time: 2024-08-02 17:18:13.530051
# --- ⏱️ Time Elapsed: 7 seconds
# --- 📐 New Embedding shape: (0,)
#
#
# --- ✅ Training Manager Fully Loaded
# --- ⏱️ Time: 2024-08-02 17:18:13.530375
# --- ⏱️ Time Elapsed: 7 seconds
#
# --- ⭐ Training Manager ⭐---
# --- ⚙️ Embedding Model  : gpt
# --- #️⃣ Number of apps loaded  : 0
# --- 📐 Feature Vectors Shape [Num Data Flow Pairs, Length of Feature Vectors]
# --- 📐 Shape : (0,)
#
# --- 🦾 TRAINING 🦾 ---
#
# --- ⚠️ Error: Embeddings Not Loaded

# %% [markdown]
# ##### 🔚 End

# %%
endTime = datetime.datetime.now()
print("\n🔚 --- End - {} --- 🔚".format(endTime))

# Assuming endTime and startTime are in seconds
totalTime = endTime - startTime
minutes = totalTime.total_seconds() // 60
seconds = totalTime.total_seconds() % 60
print("⏱️ --- Time: {:02d} minutes and {:02d} seconds --- ⏱️".format(int(minutes), int(seconds)))
# Out:
# 🔚 --- End - 2024-08-02 17:18:13.537546 --- 🔚
# ⏱️ --- Time: 00 minutes and 07 seconds --- ⏱️
